# %%
testrun = 'run2'
testname = 'latency1' #'latency1'
testStat = 'latency_5m_single_transactions.transactions' #'latency_5m_single_transactions.transactions'
testStatLocal = 'latency_5m_single_transactions.transactions_LOCAL_RPC'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# We use larger plot areas, adjust to your needs.
plt.rcParams["figure.figsize"] = (20, 10)

# %%
filepath = 'data/hbbft/' + testrun + '/' + testname +  '/' + testStat + '.csv'
filepathLocal = 'data/hbbft/' + testrun + '/' + testname +  '/' + testStatLocal + '.csv'
# print(filepath);
# df = pd.read_csv(filepath, header=None)
df = pd.read_csv(filepath)
dfLocal = pd.read_csv(filepathLocal) 

df['durationSendToConfirmation'] = df['timeReceipt'] - df['timeSend']
dfLocal['durationSendToConfirmation'] =  dfLocal['timeReceipt'] - dfLocal['timeSend']

df.head()

# print(df.timeSend)
# df['before'] = df['timeSend'].shift(1)
# df['timeSinceLastSend'] = df.timeSend - df.shift(1).timeSend
# df.head()
# df.head()
# Out:
#    internalTxID                                    transactionHash  \
# 0             1  0x02071f00a3b0ea610094fc6d3fb5261f6231b4e629da...
# 1             2  0x211664dc6bdf452b24f45565619b26aece04eb37a146...
# 2             3  0x4c209551815aa01d8da8cd03663e03757ed29705150a...
# 3             4  0xaa0ec2577627d62e062ffc9d302efd15da6fe7540ef0...
# 4             5  0x75ce4ebbefd4167d8b11237a42fcc6e5f48a393b8279...
#
#    blockNumber       timeSend   timeReceipt  timeConfirmed  \
# 0       7534.0  1585828020597  1.585828e+12   1.585828e+12
# 1       7535.0  1585828022371  1.585828e+12   1.585828e+12
# 2       7536.0  1585828029901  1.585828e+12   1.585828e+12
# 3       7537.0  1585828032689  1.585828e+12   1.585828e+12
# 4       7539.0  1585828034423  1.585828e+12   1.585828e+12
#
#    durationSendToConfirmation
# 0                      2125.0
# 1                      7934.0
# 2                      3200.0
# 3                       792.0
# 4                      9011.0

# %%
plot = plt.plot(df.durationSendToConfirmation)
plotLocal = plt.plot(dfLocal.durationSendToConfirmation)
