# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# A visualization library built on matplotlib, with a more modern look.
import seaborn as sns
sns.set(style="darkgrid")

# %%
# We use larger plot areas, adjust to your needs.
plt.rcParams["figure.figsize"] = (20, 10)

# %%
df = pd.read_csv('threshold_encryption_data.csv')

# %%
df.head()
# Out:
#    Nodes  Acks  PartsMem  AcksMem  TotalMem
# 0      1     1       233      169       402
# 1      2     4       788     1288      2076
# 2      3     9      1665     4275      5940
# 3      4    16      3760    10048     13808
# 4      5    25      5665    19525     25190

# %%
plt.plot(df.Nodes, df.TotalMem, label='On-chain Memory Use')
plt.xlabel('Number of Validators')
plt.ylabel('Memory in Bytes')
plt.legend()
# To save the plot do a file on disk:
# plt.savefig('sample.pdf')
