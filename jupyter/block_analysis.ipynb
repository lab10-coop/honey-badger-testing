# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# We use larger plot areas, adjust to your needs.
plt.rcParams["figure.figsize"] = (20, 10)

# %%
filepath = 'data/hbbft/data_test_blocks/blocks.log.txt'
df = pd.read_csv(filepath)
dfFixed = pd.read_csv('data/hbbft/data_test_blocks/blocks_no_js_checks.log.txt')

df['blockTime'] = df.timestamp - df.shift(1).timestamp
dfFixed['blockTime'] =  dfFixed.timestamp - dfFixed.shift(1).timestamp


df['txs'] = df.numberOfTransactions / df.blockTime
dfFixed['txs'] = dfFixed.numberOfTransactions / dfFixed.blockTime


# df.head()
dfFixed
# print(df.timeSend)
# df['before'] = df['timeSend'].shift(1)
# df['timeSinceLastSend'] = df.timeSend - df.shift(1).timeSend
# df.head()
# df.head()
# Out:
#      blockNumber  numberOfTransactions   gasUsed   timestamp   size  \
# 0           8374                     1     21000  1585848189    683
# 1           8375                    23    483000  1585848190   2972
# 2           8376                   710  14910000  1585848191  74422
# 3           8377                   233   4893000  1585848192  24805
# 4           8378                   442   9282000  1585848193  46545
# ..           ...                   ...       ...         ...    ...
# 131         8505                   749  15729000  1585848741  78470
# 132         8506                   218   4578000  1585848743  23250
# 133         8507                   952  19992000  1585848744  99575
# 134         8508                   226   4746000  1585848745  24084
# 135         8509                    59   1239000  1585848746   6717
#
#      blockTime    txs
# 0          NaN    NaN
# 1          1.0   23.0
# 2          1.0  710.0
# 3          1.0  233.0
# 4          1.0  442.0
# ..         ...    ...
# 131        2.0  374.5
# 132        2.0  109.0
# 133        1.0  952.0
# 134        1.0  226.0
# 135        1.0   59.0
#
# [136 rows x 7 columns]

# %%
plt.plot(dfFixed.numberOfTransactions)

# %%
#plot = plt.plot(df.blockTime)
plt.plot(dfFixed.blockTime)

# %%
# plt.plot(df.numberOfTransactions)
#plt.plot(df.txs.rolling(window=3).mean())
# plt.plot(dfFixed.numberOfTransactions)

plt.plot(dfFixed.txs.rolling(window=3).mean())
